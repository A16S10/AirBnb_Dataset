# %% [markdown]
# <a href="https://colab.research.google.com/github/A16S10/AirBnb_Dataset/blob/main/AirBnb_Booking_Analysis_EDA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Project Name-AirBnb Data Analysis**

# %% [markdown]
# **Project Type-Exploratory Data Analysis**

# %% [markdown]
# **Contribution-Individual**

# %% [markdown]
# **Name- Arshad Ansar Shaikh**

# %% [markdown]
# # **Project Summary-**

# %% [markdown]
# Airbnb is a popular online marketplace that connects people who want to rent out their property with people who are looking for accommodations in specific locales. The company has grown rapidly in recent years, and now has millions of listings in over 220 countries and regions.
#
# Data analysis is a crucial part of Airbnb's business. The company collects data on millions of listings, reviews, and other factors. This data can be used to improve the platform in a number of ways, such as:
#
# Improving security: Airbnb can use data to identify and prevent fraudulent listings and guests.
# Making business decisions: Airbnb can use data to understand which cities and neighborhoods are most popular, what types of properties are in high demand, and how much to charge for rentals.
# Understanding customer behavior: Airbnb can use data to understand how customers use the platform, what they like and dislike, and what features they would like to see added.
# Guiding marketing initiatives: Airbnb can use data to target its marketing campaigns to the right audience and track the effectiveness of those campaigns.
# Implementing innovative additional services: Airbnb can use data to identify new opportunities for growth, such as offering insurance or travel booking services.
#
# Overall, data analysis is a powerful tool that Airbnb uses to improve its business and provide a better experience for its users. By analyzing data, Airbnb can make informed decisions about everything from security to marketing to product development.
# Airbnb's data analysis also helps to improve the customer experience. For example, the company can use data to identify and fix problems with listings, such as inaccurate descriptions or poor reviews.

# %% [markdown]
# # **Github Link-**

# %% [markdown]
# https://github.com/A16S10/AirBnb_Dataset

# %% [markdown]
# # **Problem Statement**

# %% [markdown]
# **Problem Statement 1**: Identify the most popular neighborhoods for Airbnb rentals in NYC. This could be done by finding the neighborhoods with the highest number of listings, the highest average price, or the highest occupancy rate.
#
#
# **Problem Statement 2**: Determine the factors that influence the price of Airbnb rentals in NYC. This could be done by analyzing the correlation between price and other factors such as neighborhood, room type, number of bedrooms, and amenities.
#
#
# **Problem Statement 3**: Find the most popular keywords used in Airbnb listings in NYC. This could be done by analyzing the title and description of listings to identify the most common words and phrases.
#
#
# **Problem Statement 4**: Identify the neighborhoods with the highest availability of Airbnb rentals in NYC. This could be done by finding the neighborhoods with the highest number of listings that are available for booking.
#
#
# **Problem Statement 5**: Find the neighborhoods where Airbnb rentals are most expensive. This could be done by finding the neighborhoods with the highest average price for Airbnb rentals.

# %% [markdown]
# **Buisness Objective**-
#
#
#
# *   Identify the most popular neighborhoods for Airbnb rentals in NYC. This information could be used to target marketing campaigns to potential guests in
# these areas.
#
# *   Determine the factors that influence the price of Airbnb rentals in NYC. This information could be used to help hosts price their listings more competitively
#
# *   Find the most popular keywords used in Airbnb listings in NYC. This information could be used to optimize listings for search engines.
#
#
# *   Identify the neighborhoods with the highest availability of Airbnb rentals in NYC. This information could be used to help guests find available listings quickly and easily.
#
#
# *  Find the neighborhoods where Airbnb rentals are most expensive. This information could be used to help guests find more affordable options.
#
#
#
#
#
#
# .

# %% [markdown]
# # **Lets Begin Exploring Data**

# %% [markdown]
# **Data Info -**
# This dataset has around 49,000 observations in it with 16 columns and it is a mix between categorical and numeric values.

# %%
#importing necessery libraries for future analysis of the dataset
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# Loading the Dataset
Airbnb_df=pd.read_csv("/content/drive/MyDrive/Datsets/Airbnb NYC 2019.csv")

# %% [markdown]
# ## **Know the Dataset**

# %%
Airbnb_df.columns
# Out:
# Index(['id', 'name', 'host_id', 'host_name', 'neighbourhood_group',
#        'neighbourhood', 'latitude', 'longitude', 'room_type', 'price',
#        'minimum_nights', 'number_of_reviews', 'last_review',
#        'reviews_per_month', 'calculated_host_listings_count',
#        'availability_365'],
#       dtype='object')

# %%
#Dispplaying first and last 5 rows of data
Airbnb_df.head()
# Out:
#          id                                               name   host_id  \
# 0   7003697                Furnished room in Astoria apartment  20582832
# 1  22436899                                1-BR Lincoln Center  72390391
# 2  13894339    Luxury 1 bedroom apt. -stunning Manhattan views   5143901
# 3   9528920                Quiet, Clean, Lit @ LES & Chinatown   3906464
# 4  31340283  2br - The Heart of NYC: Manhattans Lower East ...   4382127
#
#   host_name neighbourhood_group    neighbourhood  latitude  longitude  \
# 0  Kathrine              Queens          Astoria  40.76810  -73.91651
# 1    Jelena           Manhattan  Upper West Side  40.77213  -73.98665
# 2      Erin            Brooklyn       Greenpoint  40.73260  -73.95739
# 3       Amy           Manhattan  Lower East Side  40.71355  -73.98507
# 4      Matt           Manhattan  Lower East Side  40.71980  -73.98566
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# ...

# %%
Airbnb_df.tail()
# Out:
#              id                                               name   host_id  \
# 48890  20523843    MARTIAL LOFT 3: REDEMPTION (upstairs, 2nd room)  15787004
# 48891  20608117                    Sunny, Quiet Room in Greenpoint   1641537
# 48892  20639628  Spacious comfortable master bedroom with nice ...  86327101
# 48893  20639792  Contemporary bedroom in brownstone with nice view  86327101
# 48894  20639914       Cozy yet spacious private brownstone bedroom  86327101
#
#           host_name neighbourhood_group       neighbourhood  latitude  \
# 48890  Martial Loft            Brooklyn            Bushwick  40.69467
# 48891        Lauren            Brooklyn          Greenpoint  40.72462
# 48892       Adeyemi            Brooklyn  Bedford-Stuyvesant  40.68173
# 48893       Adeyemi            Brooklyn  Bedford-Stuyvesant  40.68279
# 48894       Adeyemi            Brooklyn  Bedford-Stuyvesant  40.68258
#
#        longitude     room_type  price  minimum_nights  number_of_reviews  \
# ...

# %%
Airbnb_df.shape
# Out:
# (48895, 16)

# %%
Airbnb_df.describe()
# Out:
#                  id       host_id      latitude     longitude         price  \
# count  4.889500e+04  4.889500e+04  48895.000000  48895.000000  48895.000000
# mean   1.901714e+07  6.762001e+07     40.728949    -73.952170    152.720687
# std    1.098311e+07  7.861097e+07      0.054530      0.046157    240.154170
# min    2.539000e+03  2.438000e+03     40.499790    -74.244420      0.000000
# 25%    9.471945e+06  7.822033e+06     40.690100    -73.983070     69.000000
# 50%    1.967728e+07  3.079382e+07     40.723070    -73.955680    106.000000
# 75%    2.915218e+07  1.074344e+08     40.763115    -73.936275    175.000000
# max    3.648724e+07  2.743213e+08     40.913060    -73.712990  10000.000000
#
#        minimum_nights  number_of_reviews  reviews_per_month  \
# count    48895.000000       48895.000000       38843.000000
# mean         7.029962          23.274466           1.373221
# std         20.510550          44.550582           1.680442
# ...

# %%
# Check for any null values
Airbnb_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48895 entries, 0 to 48894
# Data columns (total 16 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              48895 non-null  int64
#  1   name                            48879 non-null  object
#  2   host_id                         48895 non-null  int64
#  3   host_name                       48874 non-null  object
#  4   neighbourhood_group             48895 non-null  object
#  5   neighbourhood                   48895 non-null  object
#  6   latitude                        48895 non-null  float64
#  7   longitude                       48895 non-null  float64
#  8   room_type                       48895 non-null  object
#  9   price                           48895 non-null  int64
#  10  minimum_nights                  48895 non-null  int64
#  11  number_of_reviews               48895 non-null  int64
# ...

# %%
Airbnb_df.dtypes
# Out:
# id                                  int64
# name                               object
# host_id                             int64
# host_name                          object
# neighbourhood_group                object
# neighbourhood                      object
# latitude                          float64
# longitude                         float64
# room_type                          object
# price                               int64
# minimum_nights                      int64
# number_of_reviews                   int64
# last_review                        object
# reviews_per_month                 float64
# calculated_host_listings_count      int64
# availability_365                    int64
# dtype: object

# %%
# Checking if null values in the Dataset
Airbnb_df.isnull().sum()
# Out:
# id                                    0
# name                                 16
# host_id                               0
# host_name                            21
# neighbourhood_group                   0
# neighbourhood                         0
# latitude                              0
# longitude                             0
# room_type                             0
# price                                 0
# minimum_nights                        0
# number_of_reviews                     0
# last_review                       10052
# reviews_per_month                 10052
# calculated_host_listings_count        0
# availability_365                      0
# dtype: int64

# %% [markdown]
#   **Variables Description**
#
#   ID- Unique ID
#
#   Name- Name of the listing
#
#   Host_id- Unique Host ID
#
#   Host_Name- Name of the Host
#
#   Neighbourhood_group- Location
#
#   Neighbourhood- Area
#
#   Latitude- Latitude Range
#
#   Longitude-Longtude Range
#
#   Room_Type-Type of Listing
#
#   Price- Price of listing
#
#   minimum_nights- Minimum Nights to be paid for
#
#   Number of Reviews- Number of Reviews
#
#   last_review- content of the last reveiew
#
#   reviews_per_month- Number of checks per month
#
#   Calculated_host_listings_count- Total Count
#
#   availability_365- Availability around the year

# %% [markdown]
# ### **Observation**
#
# **After loading the dataset we can see a number of things. These 16 columns provide a very rich amount of information for data exploration.We do already see some missing values and some null values which will require cleaning before starting any kind of Data exploration.**

# %% [markdown]
# # **Understanding,Cleaning and Wrangling Data**

# %%
# Remove the NaN values from the dataset
Airbnb_df.dropna(how='any',inplace=True)

# %%
Airbnb_df.isnull().sum()
# Out:
# id                                0
# name                              0
# host_id                           0
# host_name                         0
# neighbourhood_group               0
# neighbourhood                     0
# latitude                          0
# longitude                         0
# room_type                         0
# price                             0
# minimum_nights                    0
# number_of_reviews                 0
# last_review                       0
# reviews_per_month                 0
# calculated_host_listings_count    0
# availability_365                  0
# dtype: int64

# %%
Airbnb_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 38821 entries, 0 to 48894
# Data columns (total 16 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              38821 non-null  int64
#  1   name                            38821 non-null  object
#  2   host_id                         38821 non-null  int64
#  3   host_name                       38821 non-null  object
#  4   neighbourhood_group             38821 non-null  object
#  5   neighbourhood                   38821 non-null  object
#  6   latitude                        38821 non-null  float64
#  7   longitude                       38821 non-null  float64
#  8   room_type                       38821 non-null  object
#  9   price                           38821 non-null  int64
#  10  minimum_nights                  38821 non-null  int64
#  11  number_of_reviews               38821 non-null  int64
# ...

# %% [markdown]
# **There are some records which has price as 0 which is not posssible.In any another case we could have done some transformation and replaved those zeros but in this case replacing with mean or mode will simply lead to establishing incorrect relationship and incorrect analysis.So we will delete those rows with 0 price.**

# %%
# Dropping all rows with price 0
Airbnb_df =Airbnb_df.drop(index=Airbnb_df[Airbnb_df['price'] == 0].index)

# %%
Airbnb_df.shape
# Out:
# (38811, 16)

# %% [markdown]
# **From observing Dataset we can say that columns "last_review" and "reviews_per_month" does not add much value.
#  Therefore, let's proceed with removing columns that are not important and handling of missing data.**

# %%
Airbnb_df.drop(['last_review','reviews_per_month'],axis=1,inplace=True)
Airbnb_df.shape
# Out:
# (38811, 14)

# %%
# Dropping duplicates if any from Dataset
Airbnb_df.drop_duplicates()
# Out:
#              id                                               name    host_id  \
# 0       7003697                Furnished room in Astoria apartment   20582832
# 2      13894339    Luxury 1 bedroom apt. -stunning Manhattan views    5143901
# 3       9528920                Quiet, Clean, Lit @ LES & Chinatown    3906464
# 5       4737930                                 Spanish Harlem Apt    1235070
# 6      23377410  Beautiful/Spacious 1 bed luxury flat-TriBeCa/Soho   18128455
# ...         ...                                                ...        ...
# 48877  19415314  Girls only, cozy room one block from Times Square   47336995
# 48878  21869057      Spacious 2-bedroom Apt in Heart of Greenpoint   11967922
# 48879  24114389    Very Spacious bedroom, steps from CENTRAL PARK.  180661875
# 48880  25839759  Gigantic Sunny Room in Park Slope-Private Back...  167570251
# 48883  35642891                         Beautiful room in Bushwick  268138154
#
# ...

# %% [markdown]
# # **Data Visualisation**

# %%
# Finding correlation between all variables of dataset
corr = Airbnb_df.corr(method='kendall')
plt.figure(figsize=(10,6))
sns.set(style="whitegrid", color_codes=True)
font_title = { 'size': 15}
font_label = { 'size': 12}
plt.title("Correlation between variables in dataset",fontdict=font_label,fontweight='bold')
sns.heatmap(corr,fmt=".2f",cmap="crest", annot=True)
# Out:
# <ipython-input-21-ecf0747010ca>:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr = Airbnb_df.corr(method='kendall')
# <Axes: title={'center': 'Correlation between variables in dataset'}>

# %% [markdown]
# **There are no distinct co relation between 2 variables of dataset.**

# %% [markdown]
# # **Which neightbourhood group has maximum rentals  in NYC**

# %%
# Creating New Dataframe neighbourhood_df with all relevant columns for analysis purpose.

# %%
neighbourhood_df=Airbnb_df[['neighbourhood_group','neighbourhood','room_type','price','minimum_nights']]
neighbourhood_df
# Out:
#       neighbourhood_group    neighbourhood        room_type  price  \
# 0                  Queens          Astoria     Private room  10000
# 2                Brooklyn       Greenpoint  Entire home/apt  10000
# 3               Manhattan  Lower East Side     Private room   9999
# 5               Manhattan      East Harlem  Entire home/apt   9999
# 6               Manhattan          Tribeca  Entire home/apt   8500
# ...                   ...              ...              ...    ...
# 48877           Manhattan   Hell's Kitchen      Shared room     10
# 48878            Brooklyn       Greenpoint  Entire home/apt     10
# 48879           Manhattan  Upper West Side     Private room     10
# 48880            Brooklyn      Sunset Park  Entire home/apt     10
# 48883            Brooklyn         Bushwick     Private room     10
#
#        minimum_nights
# 0                 100
# 2                   5
# 3                  99
# 5                   5
# 6                  30
# ...

# %%
plt.figure(figsize=(10,6))
sns.set(style="whitegrid", color_codes=True)
font_title = {'size': 15}
font_label = {'size': 12}
plt.xlabel('Neighbourhood_group',fontdict=font_label,fontweight='bold')
plt.ylabel('Count',fontdict=font_label,fontweight='bold')
plt.title("Number of rentals in each neighbourhood group",fontdict=font_title,fontweight='bold')
sns.countplot(x='neighbourhood_group',data=neighbourhood_df,palette = "BuGn_r")
# Out:
# <Axes: title={'center': 'Number of rentals in each neighbourhood group'}, xlabel='neighbourhood_group', ylabel='count'>

# %% [markdown]
# # **Number of rentals in each neighbourhood group by Room Type**

# %%
plt.figure(figsize=(10,6))
sns.set(style="whitegrid", color_codes=True)
font_title = {'size': 15}
font_label = {'size': 12}
sns.countplot(x='neighbourhood_group',data=neighbourhood_df,hue='room_type',palette = "BuGn_r")
plt.xlabel('Neighbourhood_group',fontdict=font_label,fontweight='bold')
plt.ylabel('Count',fontdict=font_label,fontweight='bold')
plt.title("Number of rentals in each neighbourhood by Room Type",fontdict=font_title,fontweight='bold')
plt.show()

# %% [markdown]
# **From above 2 charts we can say that Manhatten has the maximum number of AirBnb rentals followed by Brooklyn.Wheras Staten Island has the least rentals.Overall the number of Entire Home or apartment is much higher when compared with other room types (private or shared).Folks often come in group with freinds and family.Solo traveling is very less at this places**

# %% [markdown]
# # **Price variation of differnt rentals depending upon neighbourhood group**

# %%
plt.figure(figsize=(10,6))
sns.set(style="whitegrid", color_codes=True)
font_title = {'size': 15}
font_label = {'size': 12}
sns.barplot(x = 'neighbourhood_group',y = 'price',hue='room_type',palette = "BuGn_r",data = neighbourhood_df)
plt.xlabel('Neighbourhood_group',fontdict=font_label,fontweight='bold')
plt.ylabel('Price',fontdict=font_label,fontweight='bold')

plt.title("Price of Different rooms in each neighbourhood",fontweight='bold',fontdict=font_title)
plt.show()

# %% [markdown]
# **Though number of rentals very less in Bronx and Staten Island we can see high volatilty is prices of shared rooms.which also implies that this 2 neighbourhood groups are in demand during particular seasons.If strategised accordingly hosts can rip off great profit.Very low volaitilty in Manhatten and Brooklyn also signifies already saturated market.If one has 2 start rental in any of the above 5 neighbourhood, i will suggest to go for Bronx or Staten Island and create shared rental place as this are very few and can give great return on Investment**

# %% [markdown]
# # **Distribution of differnt rooms in NYC**

# %%
#Creating new dataframe so that we can have count of all differnt rooms
room_count_df=neighbourhood_df.groupby('room_type').count().reset_index()
room_count_df=room_count_df[['room_type','neighbourhood_group']]
room_count_df
# Out:
#          room_type  neighbourhood_group
# 0  Entire home/apt                20320
# 1     Private room                17647
# 2      Shared room                  844

# %%
room_count_df.plot(kind='pie', y='neighbourhood_group', labels=room_count_df['room_type'],autopct='%.2f%%')
plt.legend(loc='lower right')

# Add a title
plt.title(
    label="Distribution of different rooms",
    fontdict={"fontsize":16}
    )

font_label = {'size': 12}
# Show the chart
plt.show()

# %% [markdown]
# **Shared rooms are minimal in comparison with Entire Home/Aprt. and Private room. This implies very less demand for shared rooms**

# %% [markdown]
# # **Location of  500 Most expensive rentals**

# %%
#Creating new dataframe
Airbnb_df1=Airbnb_df.sort_values(by='price',ascending=False)[:1000]
Airbnb_df1
# Out:
#             id                                               name    host_id  \
# 0      7003697                Furnished room in Astoria apartment   20582832
# 2     13894339    Luxury 1 bedroom apt. -stunning Manhattan views    5143901
# 3      9528920                Quiet, Clean, Lit @ LES & Chinatown    3906464
# 5      4737930                                 Spanish Harlem Apt    1235070
# 6     23377410  Beautiful/Spacious 1 bed luxury flat-TriBeCa/Soho   18128455
# ...        ...                                                ...        ...
# 1607  35718516             Luxury High Rise Condominium 2 Bedroom  267483864
# 1606  34676486       Luxury Manhattan Suite & uninterrupted views  261581535
# 1605  19970764  BRAND NEW MODERN 2BR 1BA,HEART OF LOWER EAST S...   22129776
# 1598  34372753                       Spacious Manhattan Apartment   40038018
# 1602  28391441  Midtown 2Bed  1.5Bath Luxury Full Kitchen, Bal...  214347105
#
# ...

# %%
#Plotting Scatterplot
plt.figure(figsize=(10,6))
sns.set(style="whitegrid", color_codes=True)
font_title = {'size': 15}
font_label = {'size': 12}
sns.scatterplot(data=Airbnb_df1,x='latitude',y='longitude',hue='neighbourhood_group')
plt.xlabel('Latitude',fontdict=font_label,fontweight='bold')
plt.ylabel('Longtude',fontdict=font_label,fontweight='bold')
plt.title("Location of 1000 Most expensive rentals",fontweight='bold',fontdict=font_title)
plt.show()

# %% [markdown]
# # **Location of rentals with maximum availability**

# %%
#Creating Dataframe with condos having avilabilty greater than 300 Days
Airbnb_df2=Airbnb_df.loc[Airbnb_df['availability_365']>300][:1000]
Airbnb_df2
# Out:
#             id                                              name    host_id  \
# 7      2953058                                     Film Location    1177497
# 16     2110145                UWS 1BR w/backyard + block from CP    2151325
# 19    33397385   Midtown Manhattan great location (Gramacy park)   16105313
# 20     2919330                  NearWilliamsburg bridge 11211 BK   14908606
# 23     1448703               Beautiful 1 Bedroom in Nolita/Soho      213266
# ...        ...                                               ...        ...
# 6956  33635292     Sonder | Stock Exchange | Sunny 1BR + Kitchen  219517861
# 6962   4659046                Large eclectic studio East Village    1420868
# 6964   7630422                        Upper West Side Perfection   37138251
# 6971  26149494  10 minutes from JFK Airport Rockaway Beach Livin  196557649
# 6982  15784377        Sixth Ave Chelsea, 1bd Serviced Apartment*   22541573
#
# ...

# %%
#Plotting Scatterplot
plt.figure(figsize=(10,6))
sns.set(style="whitegrid", color_codes=True)
font_title = {'size': 15}
font_label = {'size': 12}
sns.scatterplot(data=Airbnb_df2,x='latitude',y='longitude',hue='neighbourhood_group')
plt.xlabel('Latitude',fontdict=font_label,fontweight='bold')
plt.ylabel('Longtude',fontdict=font_label,fontweight='bold')


plt.title("Location of  rentals where availability is more than 300 days of the year",fontweight='bold',fontdict=font_title)
plt.show()

# %% [markdown]
# **Manhatten and Brooklyn are two neighbourhoods where price of rentals is maximum and have demand for Entire Home/Apartments and Private rooms.Manhatten also has maximum number of rentals with availability more than 300 days.Wheras very few rentals from Staten Island have availablity more than 300 days.This shows volaitile buinsees scneraio at Staten Island.**
#
# **After analysing Geographical location we can see that all the rentals in Mnahattenn are nearby which may resullt into low profit margin because of high comprtition.**

# %% [markdown]
# # **Boxplot of prices of rentals less than 500 US Dollers**

# %%
#Creating Datfarme with price Below 500 USD
grouped=neighbourhood_df[neighbourhood_df['price']<500]
grouped
# Out:
#       neighbourhood_group      neighbourhood        room_type  price  \
# 1235            Manhattan    Upper West Side  Entire home/apt    499
# 1236            Manhattan        Murray Hill  Entire home/apt    499
# 1237            Manhattan       East Village  Entire home/apt    499
# 1239            Manhattan          Chinatown  Entire home/apt    499
# 1242            Manhattan  Greenwich Village  Entire home/apt    499
# ...                   ...                ...              ...    ...
# 48877           Manhattan     Hell's Kitchen      Shared room     10
# 48878            Brooklyn         Greenpoint  Entire home/apt     10
# 48879           Manhattan    Upper West Side     Private room     10
# 48880            Brooklyn        Sunset Park  Entire home/apt     10
# 48883            Brooklyn           Bushwick     Private room     10
#
#        minimum_nights
# 1235               30
# 1236               30
# 1237               30
# 1239               30
# ...

# %%
#Plotting Boxplot
plt.figure(figsize=(10,6))
sns.set(style="whitegrid", color_codes=True)
sns.boxplot(data =grouped,
                    x = "neighbourhood_group",       # x axis column from data
                    y = "price",       # y axis column from data
                    width = 0.4,        # The width of the boxes
                    linewidth = 2,      # Thickness of the box lines
                    showfliers = True)
font_title = {'size': 17}
font_label = {'size': 12}


sns.boxplot(data =grouped,x ='neighbourhood_group', y ='price',palette=['#fe7474', '#8591fb','#dce110','#9a2c9d','#02508d'])
plt.xlabel('Neighbourhood Group',fontdict=font_label,fontweight='bold')
plt.ylabel('Price',fontdict=font_label,fontweight='bold')

plt.title("Boxplot of price of condos grouped by neighbourhood_group",fontweight='bold')
# Out:
# Text(0.5, 1.0, 'Boxplot of price of condos grouped by neighbourhood_group')

# %% [markdown]
# # **Countplot of top 50 Hosts in NYC**

# %%
#Creating Dataframe od top 50 Hosts
Top_50_hosts=Airbnb_df.groupby('host_id').size()
Top_50_hosts_new=Top_50_hosts.sort_values(ascending=False)
Top_50_hosts_new=Top_50_hosts_new.to_frame().reset_index()
Top_50_hosts_new=Top_50_hosts_new.iloc[:50]
Top_50_hosts_new=Top_50_hosts_new.rename(columns={0: 'Host_count','host_id':'Host_id'})
Top_50_hosts_new
# Out:
#       Host_id  Host_count
# 0   219517861         207
# 1    61391963          79
# 2    16098958          61
# 3   137358866          51
# 4     7503643          49
# 5   190921808          46
# 6    30283594          43
# 7     1475015          42
# 8   120762452          40
# 9    22541573          39
# 10    2119276          39
# 11  119669058          34
# 12  205031545          34
# 13   25237492          33
# 14  113805886          29
# 15   12243051          29
# 16   51501835          29
# 17   13347167          28
# 18  224414117          28
# 19  107434423          28
# 20     417504          28
# 21   50760546          26
# 22   26377263          22
# 23    9864136          22
# 24  131647128          20
# 25   16437254          19
# 26    7245581          19
# 27   48146336          18
# 28  159091490          17
# 29  201015598          17
# 30    9293730          16
# 31    3250450          16
# 32  177174475          16
# 33    6885157          15
# ...

# %%
# Converting All values of Host_id from int to string:
column_names=['Host_id','Host_count']
for ids in column_names:
    Top_50_hosts_new['Host_id']=Top_50_hosts_new['Host_id'].astype('string',copy=False)

print(Top_50_hosts_new.dtypes)
# Out:
# Host_id       string
# Host_count     int64
# dtype: object

# %%
#Plotting Barplot
plt.figure(figsize=(15,12))
sns.set(style="whitegrid", color_codes=True)
sns.barplot(x='Host_count',y='Host_id',data=Top_50_hosts_new,palette="Greens_d")
font_title = {'size': 15}
font_label = {'size': 12}
plt.xlabel('Host_count',fontdict=font_label,fontweight='bold')
plt.ylabel('Host_id',fontdict=font_label,fontweight='bold')

plt.title("Barplot of Host ids and Host count",fontdict=font_title,fontweight='bold')
# Out:
# Text(0.5, 1.0, 'Barplot of Host ids and Host count')

# %%
#Creating Dataframe with each Locality and respective price range
Queens_Price_df=neighbourhood_df.loc[neighbourhood_df['neighbourhood_group']=='Queens',['neighbourhood_group','price']]
Manhattan_Price_df=neighbourhood_df.loc[neighbourhood_df['neighbourhood_group']=='Manhattan',['neighbourhood_group','price']]
Brooklyn_Price_df=neighbourhood_df.loc[neighbourhood_df['neighbourhood_group']=='Brooklyn',['neighbourhood_group','price']]
Bronx_Price_df=neighbourhood_df.loc[neighbourhood_df['neighbourhood_group']=='Bronx',['neighbourhood_group','price']]
Staten_Island_Price_df=neighbourhood_df.loc[neighbourhood_df['neighbourhood_group']=='Staten Island',['neighbourhood_group','price']]

Queens_Price_df
# Out:
#       neighbourhood_group  price
# 0                  Queens  10000
# 63                 Queens   2600
# 118                Queens   1800
# 191                Queens   1250
# 271                Queens   1000
# ...                   ...    ...
# 48852              Queens     16
# 48858              Queens     15
# 48868              Queens     10
# 48874              Queens     10
# 48876              Queens     10
#
# [4572 rows x 2 columns]

# %%
# Price Range at Queens

plt.figure(figsize=(15,12))
plt.xlabel('Price',fontdict=font_label,fontweight='bold')
plt.ylabel('Count',fontdict=font_label,fontweight='bold')
plt.title("Price range at Queens",fontdict=font_title,fontweight='bold')
sns.histplot(data=Queens_Price_df, x="price", log_scale=True,color='green')

# Price Range at Brokklyn

plt.figure(figsize=(15,12))
plt.xlabel('Price',fontdict=font_label,fontweight='bold')
plt.ylabel('Count',fontdict=font_label,fontweight='bold')
plt.title("Price Range at Brokklyn",fontdict=font_title,fontweight='bold')
sns.histplot(data=Brooklyn_Price_df, x="price", log_scale=True,color='green')



# Price Range at Bronx

plt.figure(figsize=(15,12))
plt.xlabel('Price',fontdict=font_label,fontweight='bold')
plt.ylabel('Count',fontdict=font_label,fontweight='bold')
plt.title("Price Range at Bronx",fontdict=font_title,fontweight='bold')
sns.histplot(data=Bronx_Price_df, x="price", log_scale=True,color='green')




# Price Range at Staten island

plt.figure(figsize=(15,12))
plt.xlabel('Price',fontdict=font_label,fontweight='bold')
plt.ylabel('Count',fontdict=font_label,fontweight='bold')
plt.title("Price Range at Staten island",fontdict=font_title,fontweight='bold')
sns.histplot(data=Staten_Island_Price_df, x="price", log_scale=True,color='green')



# Price Range at Manhatten

plt.figure(figsize=(15,12))
plt.xlabel('Price',fontdict=font_label,fontweight='bold')
plt.ylabel('Count',fontdict=font_label,fontweight='bold')
plt.title("Price Range at Manhatten",fontdict=font_title,fontweight='bold')
sns.histplot(data=Manhattan_Price_df, x="price", log_scale=True,color='green')
# Out:
# <Axes: title={'center': 'Price Range at Manhatten'}, xlabel='Price', ylabel='Count'>

# %% [markdown]
# **From above Histogram,we can confidently say that price range at Manahtten and Brooklyn is way greater than that of other 3 neighbourhood groups.Tall bars in both this neighbourhood groups shows that this 2 groups have overall very high rental price in comparison.Hostogram that of Bronx is right skewed which mean majority of rental places in Bronx have very less price in comparison.**

# %% [markdown]
# # **Find 30 Most used words in the name of rentals**

# %%
# Creating list of words from column Name
List_of_words=Airbnb_df['name'].to_list()
Unique_words=[]
Unique_words=[words for words in List_of_words if words not in Unique_words]

# %%
#Creating  list of sentences for specified rows

List_of_words1=Unique_words[0:4000]
List_of_words2=Unique_words[4000:8000]
List_of_words3=Unique_words[8000:12000]
List_of_words4=Unique_words[12000:16000]
List_of_words5=Unique_words[16000:20000]
List_of_words6=Unique_words[20000:24000]
List_of_words7=Unique_words[24000:28000]
List_of_words8=Unique_words[28000:32000]
List_of_words9=Unique_words[32000:36000]
List_of_words10=Unique_words[36000:]

# %%
# Creating list of words

words1=[word for sentence in List_of_words1 for word in sentence.split()]
words2=[word for sentence in List_of_words2 for word in sentence.split()]
words3=[word for sentence in List_of_words3 for word in sentence.split()]
words4=[word for sentence in List_of_words4 for word in sentence.split()]
words5=[word for sentence in List_of_words5 for word in sentence.split()]
words6=[word for sentence in List_of_words6 for word in sentence.split()]
words7=[word for sentence in List_of_words7 for word in sentence.split()]
words8=[word for sentence in List_of_words8 for word in sentence.split()]
words9=[word for sentence in List_of_words9 for word in sentence.split()]
words10=[word for sentence in List_of_words10 for word in sentence.split()]

# %%
# Defining function to create dictionary with word and its count
def CountFrequncy(my_list):
    frequncy={}
    for word in my_list:
        if word in frequncy:
            frequncy[word]+=1
        else:
            frequncy[word]=1
    for key,value in frequncy.items():
        if value> 50:
            print("%s : % d" % (key, value))
    return frequncy

# %%
# Creating Dictionaries of words and frequency
dict1=CountFrequncy(words1)
dict2=CountFrequncy(words2)
dict3=CountFrequncy(words3)
dict4=CountFrequncy(words4)
dict6=CountFrequncy(words6)
dict7=CountFrequncy(words7)
dict8=CountFrequncy(words8)
dict9=CountFrequncy(words9)
dict10=CountFrequncy(words10)
dict5=CountFrequncy(words5)
# Out:
# in :  954
# apartment :  145
# Luxury :  283
# 1 :  206
# bedroom :  188
# Manhattan :  209
# & :  249
# Apt :  203
# Location :  58
# of :  257
# 1BR :  82
# + :  154
# from :  78
# Midtown :  162
# 2 :  590
# Beautiful :  170
# Bedroom :  335
# - :  225
# Village :  274
# with :  280
# Private :  150
# Duplex :  154
# Townhouse :  103
# West :  194
# by :  73
# City :  56
# 3 :  261
# Bed :  95
# private :  52
# Garden :  64
# Amazing :  96
# Chelsea :  120
# 2BR :  127
# Apartment :  266
# NYC :  194
# Cozy :  106
# Stunning :  62
# Brooklyn :  190
# Brownstone :  97
# Upper :  81
# East :  209
# Penthouse :  77
# Central :  196
# Park :  233
# Modern :  155
# Bath :  93
# 5 :  53
# BR :  105
# Suite :  67
# Heart :  80
# loft :  57
# Studio :  126
# New :  114
# to :  206
# Kitchen :  63
# Large :  115
# 4 :  89
# for :  83
# Huge :  69
# Loft :  269
# House :  72
# Spacious :  235
# the :  205
# heart :  83
# near :  73
# Soho :  59
# Home :  106
# Prime :  68
# Side :  78
# ...

# %%
#Removing Non Alpha Numeric Characters
clean_dict1 = {key: value for key, value in dict1.items() if key.isalnum()}
clean_dict2 = {key: value for key, value in dict2.items() if key.isalnum()}
clean_dict3 = {key: value for key, value in dict3.items() if key.isalnum()}
clean_dict4 = {key: value for key, value in dict4.items() if key.isalnum()}
clean_dict5 = {key: value for key, value in dict5.items() if key.isalnum()}
clean_dict6 = {key: value for key, value in dict1.items() if key.isalnum()}
clean_dict7 = {key: value for key, value in dict2.items() if key.isalnum()}
clean_dict8 = {key: value for key, value in dict3.items() if key.isalnum()}
clean_dict9 = {key: value for key, value in dict4.items() if key.isalnum()}
clean_dict10 = {key: value for key, value in dict5.items() if key.isalnum()}

# %%
# Removing numeric characters from keys
clean_dict_1 = {key: value for key, value in dict1.items() if key.isalpha()}
clean_dict_2 = {key: value for key, value in dict2.items() if key.isalpha()}
clean_dict_3 = {key: value for key, value in dict3.items() if key.isalpha()}
clean_dict_4 = {key: value for key, value in dict4.items() if key.isalpha()}
clean_dict_5 = {key: value for key, value in dict5.items() if key.isalpha()}
clean_dict_6 = {key: value for key, value in dict6.items() if key.isalpha()}
clean_dict_7 = {key: value for key, value in dict7.items() if key.isalpha()}
clean_dict_8 = {key: value for key, value in dict8.items() if key.isalpha()}
clean_dict_9 = {key: value for key, value in dict9.items() if key.isalpha()}
clean_dict_10 = {key: value for key, value in dict10.items() if key.isalpha()}

# %%
#Sorting dictionary in descending order of count of words and taking first 500
sorted_dict_1=dict(sorted(clean_dict_1.items(), key=lambda item:item[1],reverse=True)[:500])
sorted_dict_2=dict(sorted(clean_dict_2.items(), key=lambda item:item[1],reverse=True)[:500])
sorted_dict_3=dict(sorted(clean_dict_3.items(), key=lambda item:item[1],reverse=True)[:500])
sorted_dict_4=dict(sorted(clean_dict_4.items(), key=lambda item:item[1],reverse=True)[:500])
sorted_dict_5=dict(sorted(clean_dict_5.items(), key=lambda item:item[1],reverse=True)[:500])
sorted_dict_6=dict(sorted(clean_dict_6.items(), key=lambda item:item[1],reverse=True)[:500])
sorted_dict_7=dict(sorted(clean_dict_7.items(), key=lambda item:item[1],reverse=True)[:500])
sorted_dict_8=dict(sorted(clean_dict_8.items(), key=lambda item:item[1],reverse=True)[:500])
sorted_dict_9=dict(sorted(clean_dict_9.items(), key=lambda item:item[1],reverse=True)[:500])
sorted_dict_10=dict(sorted(clean_dict_10.items(), key=lambda item:item[1],reverse=True)[:500])

# %%
# Combining all dictionaries into one big dictionary
combined_dict={}
combined_dict.update(sorted_dict_1)
combined_dict.update(sorted_dict_2)
combined_dict.update(sorted_dict_3)
combined_dict.update(sorted_dict_4)
combined_dict.update(sorted_dict_5)
combined_dict.update(sorted_dict_6)
combined_dict.update(sorted_dict_7)
combined_dict.update(sorted_dict_8)
combined_dict.update(sorted_dict_9)

# %%
# Sorting Dictionary in descending order of count of words
combined_dict_new=dict(sorted(combined_dict.items(), key=lambda item:item[1],reverse=True))
combined_dict_new
# Out:
# {'in': 977,
#  'Room': 603,
#  'room': 575,
#  'Private': 449,
#  'Cozy': 328,
#  'to': 317,
#  'Brooklyn': 292,
#  'Bedroom': 208,
#  'and': 193,
#  'Manhattan': 146,
#  'with': 141,
#  'for': 140,
#  'Bushwick': 140,
#  'bedroom': 139,
#  'Spacious': 119,
#  'the': 113,
#  'a': 113,
#  'private': 110,
#  'Stock': 106,
#  'Exchange': 106,
#  'near': 103,
#  'Sunny': 95,
#  'apartment': 94,
#  'from': 94,
#  'Apartment': 91,
#  'of': 90,
#  'Beautiful': 81,
#  'Bed': 77,
#  'cozy': 77,
#  'NYC': 75,
#  'Near': 70,
#  'Large': 65,
#  'A': 61,
#  'Shared': 60,
#  'Park': 59,
#  'min': 59,
#  'JFK': 59,
#  'Quiet': 54,
#  'Heights': 54,
#  'train': 53,
#  'Bright': 51,
#  'The': 50,
#  'Great': 49,
#  'Home': 47,
#  'LGA': 47,
#  'Comfy': 46,
#  'Nice': 46,
#  'Harlem': 45,
#  'close': 45,
#  'shared': 45,
#  'Williamsburg': 43,
#  'on': 43,
#  'bed': 43,
#  'home': 43,
#  'ROOM': 43,
#  'Wyndham': 41,
#  'Clean': 41,
#  'Small': 40,
#  'Comfortable': 39,
#  'GUEST': 36,
#  'Apt': 35,
# ...

# %%
# New list is created to remove this prepositions from combined dictionary
remove_list=['in','with','of','to','the','and','on','for','from','bye','a','A','The','In','L','at','TO']

# %%
# Removing prespositions from dictionary using remove list
Final_dict={key:value for key,value in combined_dict_new.items() if key not in remove_list}

# %%
# Creating Dataframe
Top_30_most_used_words=pd.DataFrame(list(Final_dict.items()),columns=['Word','Count'])
# Converting all words in lower case
Top_30_most_used_words['Word']=Top_30_most_used_words['Word'].str.lower()
# Removing Duplicates
Top_30_most_used_words.drop_duplicates()
# Grouping words and taking total count of them
Top_30_most_used_words_new=Top_30_most_used_words.groupby('Word').sum().reset_index()
#Arranging words in descending order and taking top 30
Top_30_most_used_words_new=Top_30_most_used_words_new.sort_values('Count',ascending=False)[:30]
Top_30_most_used_words_new
print(Top_30_most_used_words_new)
# Out:
#           Word  Count
# 473       room   1221
# 432    private    576
# 144       cozy    420
# 54     bedroom    359
# 82    brooklyn    302
# 17   apartment    192
# 379       near    181
# 348  manhattan    160
# 90    bushwick    156
# 512   spacious    149
# 548      sunny    133
# 52         bed    126
# 489     shared    117
# 190   exchange    106
# 528      stock    106
# 49   beautiful    106
# 271       home     96
# 311      large     86
# 122      close     81
# 444      quiet     80
# 569      train     76
# 393        nyc     75
# 361        min     75
# 19         apt     73
# 413       park     72
# 78      bright     70
# 243      great     69
# 119      clean     67
# 541     subway     66
# 132      comfy     65

# %%
#Plotting Barplot
plt.figure(figsize=(15,12))
sns.set(style="whitegrid", color_codes=True)
sns.barplot(x='Count',y='Word',data=Top_30_most_used_words_new,palette="Greens_d")
font_title = {'size': 15}
font_label = {'size': 12}
plt.xlabel('Words_Count',fontdict=font_label,fontweight='bold')
plt.ylabel('Words',fontdict=font_label,fontweight='bold')
plt.title("Top 30 most used words",fontdict=font_title,fontweight='bold')
# Out:
# Text(0.5, 1.0, 'Top 30 most used words')

# %%
#Importing wordcloud library for visual representation
from wordcloud import WordCloud, STOPWORDS

wc = WordCloud(background_color="black", max_words=1000, stopwords=STOPWORDS)
wordcloud = WordCloud(width=1000, height=400).generate('Top_30_most_used_words_new')
wc.generate_from_frequencies(Top_30_most_used_words_new["Word"].value_counts())

# plotting wordcloud

plt.figure(figsize=(15,8))
plt.imshow(wc, interpolation="bilinear")
plt.axis("off")
plt.show()

# %% [markdown]
# # **Solution to Buisness Objective:**

# %% [markdown]
# **Target group traveling:** The analysis of the two charts shows that the majority of Airbnb rentals in Manhattan and Brooklyn are entire homes or apartments, which are typically rented by groups of friends or families. This suggests that hosts should focus on accommodating these types of travelers by providing spacious and well-equipped accommodations.
#
#
# **Volatile prices:** The high volatility of prices for shared rooms in Bronx and Staten Island indicates that these neighborhoods are in demand during certain seasons. Hosts who are strategic about their pricing can capitalize on this demand and generate significant profits.
#
#
# **Investment strategy:** If you are considering starting an Airbnb rental, I would recommend targeting Bronx or Staten Island and creating a shared rental space. There are very few of these types of rentals in these neighborhoods, so they can be very profitable.
#
#
# **Market saturation:** Manhattan and Brooklyn are already saturated markets, so it may be difficult to generate a high profit margin in these areas. However, there is still demand for entire homes and apartments in these neighborhoods, so they could be a good option for hosts who are looking for a steady stream of income.
#
#
# **Geographical location:** The fact that all of the rentals in Manhattan are located close together suggests that there is a lot of competition in this area. This could lead to lower profit margins for hosts.
#
#
# **Rental names:**The analysis of rental names shows that the most popular words are "room," "cozy," "private," and "bedroom." These words are likely to be effective in attracting potential guests, so I would recommend using them in your rental names.
